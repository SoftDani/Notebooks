# %%
import numpy as np
import pandas as pd

import os

import matplotlib.pyplot as plt
import seaborn as sns

# para poder ver todas las columnas y filas 
pd.options.display.max_rows = 50
pd.options.display.max_columns = 60

# %%
print(os.path.abspath(os.getcwd()))
# Out:
# C:\Users\Dani\OneDrive - SOFTOUR SISTEMAS S.L\Data_Science\almacen

# %%
ruta=os.path.join("data",'taller_vehiculo.csv')
df= pd.read_csv(ruta, sep='|', index_col = False)#, on_bad_lines='skip')

# %%
df
# Out:
#        anyparte  numparte  numlinea                                   descrip  \
# 0          2007     70946         1                       KIT DE EMPALME G-16
# 1          2007     70946         2                 MANGUERA NEWCLIMA 3/4 16M
# 2          2007     71029         1                          KIT EMPALME G-12
# 3          2007     71029         2                    LATIGUILLO R5 7/8 7800
# 4          2007     71029         3                    LATIGUILLO R5 7/8 1020
# ...         ...       ...       ...                                       ...
# 97842      2022   2204895         3                     MOTOR CONDENSADORA PB
# 97843      2022   2204895         4         ELECTRONICA DE MOTOR CONDENSADORA
# 97844      2022   2204895         5  ART.5 APTO.11.1 EPIG.1.8 R-134a LEY 16/2
# 97845      2022   2204986         1                           BATERIA 225 AMP
# 97846      2022   2205055         1          CULATA COMPLETA DE AGUA MERCEDES
#
#        cantidad  precio  importe                    prove mat  \
# 0           1.0   60.72    51.61     FRIGICOLL VALENCIA, S.A.
# 1           1.0   16.81    16.81     FRIGICOLL VALENCIA, S.A.
# 2           1.0   28.85    24.52     FRIGICOLL VALENCIA, S.A.
# 3           1.0  168.24   109.36    SUMINISTROS HYDRACO, S.L.
# 4           1.0   22.01    14.31    SUMINISTROS HYDRACO, S.L.
# ...         ...     ...      ...                          ...
# 97842       1.0   82.00    82.00  IRIZAR SOCIEDAD COOPERATIVA
# 97843       1.0   45.42    45.42  IRIZAR SOCIEDAD COOPERATIVA
# 97844       7.0   21.45   150.15                KIMIKAL, S.L.
# 97845       2.0  133.80   267.60                     EUROPART
# 97846       1.0  185.00   185.00                     EUROPART
#
#                                           nomartic    fec_alta  preciouc  \
# 0                              KIT DE EMPALME G-16  2007-06-06   56.0660
# 1                        MANGUERA NEWCLIMA 3/4 16M  2007-06-06   16.8100
# 2                                 KIT EMPALME G-12  2007-06-07   24.5200
# 3                           LATIGUILLO R5 7/8 7800  2013-02-26   92.0205
# 4                           LATIGUILLO R5 7/8 1020  2011-07-20   21.5085
# ...                                            ...         ...       ...
# 97842                        MOTOR CONDENSADORA PB  2021-09-10   82.0000
# 97843            ELECTRONICA DE MOTOR CONDENSADORA  2022-02-17   45.4159
# 97844  ART.5 APTO.11.1 EPIG.1.8 R-134a LEY 16/2013  2015-04-14   21.4500
# 97845                              BATERIA 225 AMP  2013-03-11  133.8000
# 97846             CULATA COMPLETA DE AGUA MERCEDES  2018-05-23  185.0000
#
#        ctr_stock       nomalmac                    prove art  \
# 0              1  ALMACEN QUART     FRIGICOLL VALENCIA, S.A.
# 1              1  ALMACEN QUART     FRIGICOLL VALENCIA, S.A.
# 2              1  ALMACEN QUART     FRIGICOLL VALENCIA, S.A.
# 3              1  ALMACEN QUART    SUMINISTROS HYDRACO, S.L.
# 4              1  ALMACEN QUART    SUMINISTROS HYDRACO, S.L.
# ...          ...            ...                          ...
# 97842          1  ALMACEN QUART  IRIZAR SOCIEDAD COOPERATIVA
# 97843          1  ALMACEN QUART  IRIZAR SOCIEDAD COOPERATIVA
# 97844          0  ALMACEN QUART                KIMIKAL, S.L.
# 97845          1  ALMACEN QUART                     EUROPART
# 97846          1  ALMACEN QUART                     EUROPART
#
#                         nomfamia  nomunida codigbus    fechaent  numkms  \
# 0                         VARIOS  UNIDADES     B114  2007-06-04  423218
# 1                         VARIOS  UNIDADES     B114  2007-06-04  423218
# 2                         VARIOS  UNIDADES     B114  2007-06-08  424944
# 3                         VARIOS  UNIDADES     B114  2007-06-08  424944
# 4                         VARIOS  UNIDADES     B114  2007-06-08  424944
# ...                          ...       ...      ...         ...     ...
# 97842  AIRE ACOND. Y CALEFACCION  UNIDADES     T379  2022-06-07  600000
# 97843         MATERIAL ELECTRICO  UNIDADES     T379  2022-06-07  600000
# 97844                     VARIOS  UNIDADES     T379  2022-06-07  600000
# 97845         MATERIAL ELECTRICO  UNIDADES     T379  2022-06-08  600000
# 97846     BOMBAS AGUA Y VALVULAS  UNIDADES   RMA108  2022-06-10       0
#
#        siniestro                  descripcion                      cliente  \
# 0              0     FRIGICOLL VALENCIA, S.A.     FRIGICOLL VALENCIA, S.A.
# 1              0     FRIGICOLL VALENCIA, S.A.     FRIGICOLL VALENCIA, S.A.
# 2              0     FRIGICOLL VALENCIA, S.A.     FRIGICOLL VALENCIA, S.A.
# 3              0    SUMINISTROS HYDRACO, S.L.    SUMINISTROS HYDRACO, S.L.
# 4              0    SUMINISTROS HYDRACO, S.L.    SUMINISTROS HYDRACO, S.L.
# ...          ...                          ...                          ...
# 97842          0  IRIZAR SOCIEDAD COOPERATIVA  IRIZAR SOCIEDAD COOPERATIVA
# 97843          0  IRIZAR SOCIEDAD COOPERATIVA  IRIZAR SOCIEDAD COOPERATIVA
# 97844          0                KIMIKAL, S.L.                KIMIKAL, S.L.
# 97845          0                     EUROPART                     EUROPART
# 97846          0                     EUROPART                     EUROPART
#
#        id_vehiculo     matricul  edad  numempre  nomempre        marca  \
# 0           1348.0      3570BSX  20.0        43     Buñol          MAN
# 1           1348.0      3570BSX  20.0        43     Buñol          MAN
# 2           1348.0      3570BSX  20.0        43     Buñol          MAN
# 3           1348.0      3570BSX  20.0        43     Buñol          MAN
# 4           1348.0      3570BSX  20.0        43     Buñol          MAN
# ...            ...          ...   ...       ...       ...          ...
# 97842       1387.0      1694HNR   9.0         2  Transvia  SIN ASIGNAR
# 97843       1387.0      1694HNR   9.0         2  Transvia  SIN ASIGNAR
# 97844       1387.0      1694HNR   9.0         2  Transvia  SIN ASIGNAR
# 97845       1387.0      1694HNR   9.0         2  Transvia  SIN ASIGNAR
# 97846       1364.0  SIN ASIGNAR  -1.0       138    Roymar  SIN ASIGNAR
#
#             modelo    carrocero         tipo   totkilom dns_vehiculo  \
# 0            18310  SIN ASIGNAR       URBANO  2000000.0       bunyol
# 1            18310  SIN ASIGNAR       URBANO  2000000.0       bunyol
# 2            18310  SIN ASIGNAR       URBANO  2000000.0       bunyol
# 3            18310  SIN ASIGNAR       URBANO  2000000.0       bunyol
# 4            18310  SIN ASIGNAR       URBANO  2000000.0       bunyol
# ...            ...          ...          ...        ...          ...
# 97842  SIN ASIGNAR       BEULAS       NORMAL        0.0     transvia
# 97843  SIN ASIGNAR       BEULAS       NORMAL        0.0     transvia
# 97844  SIN ASIGNAR       BEULAS       NORMAL        0.0     transvia
# 97845  SIN ASIGNAR       BEULAS       NORMAL        0.0     transvia
# 97846  SIN ASIGNAR  SIN ASIGNAR  SIN ASIGNAR   276189.0       roymar
#
#        importe_teorico  descuento
# 0                60.72       9.11
# 1                16.81       0.00
# 2                28.85       4.33
# 3               168.24      58.88
# 4                22.01       7.70
# ...                ...        ...
# 97842            82.00       0.00
# 97843            45.42       0.00
# 97844           150.15       0.00
# 97845           267.60       0.00
# 97846           185.00       0.00
#
# [97847 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['anyparte', 'numparte', 'numlinea', 'descrip', 'cantidad', 'precio',
#        'importe', 'prove mat', 'nomartic', 'fec_alta', 'preciouc', 'ctr_stock',
#        'nomalmac', 'prove art', 'nomfamia', 'nomunida', 'codigbus', 'fechaent',
#        'numkms', 'siniestro', 'descripcion', 'cliente', 'id_vehiculo',
#        'matricul', 'edad', 'numempre', 'nomempre', 'marca', 'modelo',
#        'carrocero', 'tipo', 'totkilom', 'dns_vehiculo', 'importe_teorico',
#        'descuento'],
#       dtype='object')

# %%
df.groupby('nomartic').nomartic.count().max()
# Out:
# 1687

# %%
df.groupby('nomartic').nomartic.count()[df.groupby('nomartic').nomartic.count()==df.groupby('nomartic').nomartic.count().max()]
# Out:
# nomartic
# QUITAR/PONER RUEDA DEL VEHÍCULO    1687
# Name: nomartic, dtype: int64

# %%
df.groupby('nomartic').nomartic.count()[df.groupby('nomartic').nomartic.count()>500].sort_values(ascending=False)
# Out:
# nomartic
# QUITAR/PONER RUEDA DEL VEHÍCULO     1687
# EXTINTORES                          1523
# MONTAR/DESMONTAR NEUMÁTICO NUEVO     920
# EQULIBRADO DINÁMICO                  914
# PORTES                               868
# MATERIAL DE PRECINTADO               804
# MONTAR/DESMONTAR NEUMÁTICO USADO     710
# PLACA FRENO                          693
# VERIFICACION TACOGRAFO               601
# PASTA DE LUNAS                       569
# PORTES DHL                           548
# SIGNUS(RD 1619/2005)                 513
# Name: nomartic, dtype: int64

# %%
df.groupby('nomartic').nomartic.count()
# Out:
# nomartic
#  PILOTO POSTERIOR IZQ.JUMPER/DUCATO           5
# (NP1) NEUMATICOS FORD MOTORCRAFT 2 TODOS      1
# (NP3) MANTENIMIENTO FORD MOTORCARFT TODOS     4
# (NP4) A/A-RECUP., EVACUACIÓN Y CARGA         10
# (NP4) CAMBIO DE ACEITE                        1
#                                              ..
# tubo flex 15x75-1                             1
# valvula niveladora                            1
# ÁNGULO ESCALÓN AMARILLO                       1
# ÉMBOLO                                        5
# ÚTIL PARA MÁQUINA DE RUEDAS TIPTOP            1
# Name: nomartic, Length: 22527, dtype: int64

# %%
df_ext=df[df['nomartic']=='EXTINTORES']

# %%
df_ext[['anyparte','cantidad','precio','importe','preciouc']]
# Out:
#        anyparte  cantidad   precio  importe  preciouc
# 36         2008       1.0  14.1900    14.19      6.55
# 69         2010       2.0   8.2900    16.58      6.55
# 77         2011       2.0   9.8900    19.77      6.55
# 120        2012       2.0   9.5700    19.14      6.55
# 172        2013       2.0   8.1000    16.20      6.55
# ...         ...       ...      ...      ...       ...
# 97498      2021       2.0   6.5129    13.03      6.55
# 97560      2022       2.0   7.6179    15.24      6.55
# 97577      2021       2.0   4.9000     9.80      6.55
# 97616      2022       2.0   3.3705     6.74      6.55
# 97726      2022       2.0   4.6391     9.28      6.55
#
# [1523 rows x 5 columns]

# %% [markdown]
# ***Precio de la ultima compra es constante es algo  que no debería ser así***

# %% [markdown]
# # Precio articulos

# %%
def precio_art (art,df):
    df_art=df[df['nomartic']==art]
    df_art_precio=df_art.groupby('anyparte').precio.mean()
    #display(df_ext_precio)
    df_art_preciouc=df_art.groupby('anyparte').preciouc.mean()
####
    print( 'Precio minimo ultima compra: ', round(df_art_preciouc.min(),2),'\n')
    print( 'Precio medio: ', round(df_art_precio.mean(),2),'\n')
###
    x_precio = df_art_precio.index
    y_precio= df_art_precio
    x_preciouc = df_art_preciouc.index
    y_preciouc=df_art_preciouc

    fig,axis = plt.subplots(1,1, figsize=(15,8))
    axis.plot(x_precio,y_precio,'go-',label='precio',linewidth=1,alpha=1) # creación del gráfico
    axis.plot(x_preciouc,y_preciouc,'bx-.',label='precio ultima compra',linewidth=1) # creación del gráfico
#
    axis.legend(loc='best')
    plt.grid()
    plt.show()

# %%
art='EXTINTORES'
precio_art (art,df)
# Out:
# Precio minimo ultima compra:  6.55
#
# Precio medio:  8.35

# %% [markdown]
#  grafico importe por autobus

# %%
art='QUITAR/PONER RUEDA DEL VEHÍCULO'
precio_art (art,df)
# Out:
# Precio minimo ultima compra:  7.73
#
# Precio medio:  7.21

# %%
art='MONTAR/DESMONTAR NEUMÁTICO NUEVO'
precio_art (art,df)
# Out:
# Precio minimo ultima compra:  4.75
#
# Precio medio:  7.13

# %%
art='EQULIBRADO DINÁMICO'
precio_art (art,df)
# Out:
# Precio minimo ultima compra:  5.0
#
# Precio medio:  13.12

# %% [markdown]
# # Gasto por autobus

# %%
df.groupby('codigbus').codigbus.count()[df.groupby('codigbus').codigbus.count()>700].sort_values(ascending=False)
# Out:
# codigbus
# K000    2239
# T222    1356
# T241    1290
# H094     928
# T227     828
# I707     805
# F176     765
# E651     728
# D112     726
# T251     722
# A109     712
# Name: codigbus, dtype: int64

# %%
def gasto_bus(df, bus) :
    df_bus=df[df['codigbus']==bus]
    #df_bus.groupby('nomfamia').importe.max().sort_values(ascending=False)
    #df_bus.groupby('nomfamia').importe.max().sort_values(ascending=False)
    
    
    ### gasto Total
    x_bus=df_bus.groupby('nomfamia').importe.sum().sort_values(ascending=False)
    y_bus=df_bus.groupby('nomfamia').importe.sum().sort_values(ascending=False).index

    plt.figure(figsize=(15,15))
    sns.set(style='darkgrid')

    sns.barplot(x=x_bus, y=y_bus,data=df)
    plt.title('Autobus '+bus+' Gasto total por familia')
    plt.show()
  
    ##### Gasto total por año
    
    y_bus=df_bus.groupby('anyparte').importe.sum()
    x_bus=list(df_bus.groupby('anyparte').importe.sum().index)


    fig,axis = plt.subplots(1,1, figsize=(15,8))
    axis.plot(x_bus,y_bus,'go-',label='importe',linewidth=1,alpha=1) # creación del gráfico
    plt.xticks(x_bus)
    axis.legend(loc='best')
    plt.title('Autobus '+bus+' Gasto total por año')
    plt.grid()
    plt.show() 
    
   
    ##### detalles del gasto Total
    año_max = df_bus.groupby('anyparte').importe.sum().idxmax()
    print('\nAño con mayor gasto total, ', año_max ,'distribuido: \n')
    
    df_bus_año=df_bus[df_bus['anyparte']==año_max]
    gasto_año_max=df_bus_año.groupby('nomfamia').importe.sum().sort_values(ascending=False)
    display(gasto_año_max)
    
    print('\n')
    ### gasto medio
    x_bus=df_bus.groupby('nomfamia').importe.mean().sort_values(ascending=False)
    y_bus=df_bus.groupby('nomfamia').importe.mean().sort_values(ascending=False).index

    plt.figure(figsize=(15,15))
    sns.set(style='darkgrid')

    sns.barplot(x=x_bus, y=y_bus,data=df)
    plt.title('Autobus '+bus+' Gasto medio por familia')
    plt.show()
    #####
    ##### Gasto medio por año
    
    y_bus=df_bus.groupby('anyparte').importe.mean()
    x_bus=list(df_bus.groupby('anyparte').importe.mean().index)


    fig,axis = plt.subplots(1,1, figsize=(15,8))
    axis.plot(x_bus,y_bus,'go-',label='importe',linewidth=1,alpha=1) # creación del gráfico
    plt.xticks(x_bus)
    axis.legend(loc='best')
    plt.title('Autobus '+bus+' Gasto  medio por año')
    plt.grid()
    plt.show() 
    
    ##### detalles del gasto medio
    año_max = df_bus.groupby('anyparte').importe.mean().idxmax()
    print('\nAño con mayor gasto medio, ', año_max ,'distribuido: \n')
    
    df_bus_año=df_bus[df_bus['anyparte']==año_max]
    gasto_año_max=df_bus_año.groupby('nomfamia').importe.mean().sort_values(ascending=False)
    display(gasto_año_max)
    
    #display(df_bus.sample(5))

# %%
bus_max=df.groupby('codigbus').nomartic.count().idxmax()
bus_max
# Out:
# 'K000'

# %%
df_bus_max.groupby('nomfamia').importe.mean().sort_values(ascending=False)
# Out:
# nomfamia
# ACEITES Y LUBRICANTES        471.342941
# LUNAS                        403.405000
# AIRE ACOND. Y CALEFACCION    399.307361
# SUSPENSION                   355.595625
# BOMBAS AGUA Y VALVULAS       287.740000
# FRENOS                       244.652222
# VARIOS                       244.028639
# MANO DE OBRA                 216.060606
# RESIDUOS                     157.507500
# IMAGEN Y SONIDO              144.300000
# CARROCERIA                   135.096591
# MATERIAL CAJAS CAMBIO        103.710000
# ELEMENTOS MOTOR              100.012667
# CORREAS                       89.746825
# RODAMIENTOS                   88.283478
# CUBIERTAS                     76.106000
# MATERIAL MECANICOS            74.084000
# FILTROS                       70.128052
# MATERIAL ELECTRICO            62.596108
# MATERIAL PINTURA              58.823088
# PRODUCTOS QUIMICOS            54.097187
# MATERIAL LIMPIEZA             50.472593
# LATIGUILLO/MANGUITO/CABLE     42.635814
# HERRAMIENTAS                  37.580635
# TORNILLERIA Y VARIOS          21.298530
# ALMACEN COMPROMISOS            2.660000
# Name: importe, dtype: float64

# %%
x_bus_max=df_bus_max.groupby('anyparte').importe.median().index
x_bus_max
# Out:
# Int64Index([2016, 2017, 2018, 2019, 2020, 2021, 2022], dtype='int64', name='anyparte')

# %%
año_max = df_bus_max.groupby('anyparte').importe.sum().idxmax()
año_max
# Out:
# 2018

# %%
gasto_bus(df, bus_max)
# Out:
# Año con mayor gasto total,  2018 distribuido:
# nomfamia
# MATERIAL ELECTRICO           14984.72
# AIRE ACOND. Y CALEFACCION     8441.16
# VARIOS                        6105.59
# FRENOS                        5110.84
# CARROCERIA                    5065.39
# MATERIAL PINTURA              3624.93
# MANO DE OBRA                  2650.00
# SUSPENSION                    2400.00
# ELEMENTOS MOTOR               2175.90
# BOMBAS AGUA Y VALVULAS        1797.44
# ACEITES Y LUBRICANTES         1725.42
# TORNILLERIA Y VARIOS          1314.64
# LATIGUILLO/MANGUITO/CABLE     1155.93
# FILTROS                       1057.00
# CORREAS                        993.14
# MATERIAL LIMPIEZA              393.06
# HERRAMIENTAS                   388.60
# MATERIAL MECANICOS             320.40
# PRODUCTOS QUIMICOS             248.22
# RODAMIENTOS                    234.31
# CUBIERTAS                       68.73
# Name: importe, dtype: float64
# Año con mayor gasto medio,  2022 distribuido:
# nomfamia
# ACEITES Y LUBRICANTES        716.300000
# AIRE ACOND. Y CALEFACCION    320.231000
# SUSPENSION                   285.600000
# MATERIAL MECANICOS           253.800000
# VARIOS                       228.914706
# MATERIAL PINTURA             164.747273
# RESIDUOS                     151.470000
# CARROCERIA                   149.691667
# RODAMIENTOS                  148.175000
# CORREAS                      142.120000
# FILTROS                      127.913333
# BOMBAS AGUA Y VALVULAS        86.200000
# MATERIAL ELECTRICO            75.071522
# PRODUCTOS QUIMICOS            59.785000
# LATIGUILLO/MANGUITO/CABLE     42.475000
# TORNILLERIA Y VARIOS          40.270625
# MATERIAL LIMPIEZA             37.560000
# FRENOS                        29.400000
# HERRAMIENTAS                  21.100000
# ELEMENTOS MOTOR               20.793333
# Name: importe, dtype: float64

# %%
df.groupby('codigbus').nomartic.count()[df.groupby('codigbus').nomartic.count()>700].sort_values(ascending=False)
# Out:
# codigbus
# K000    2239
# T222    1356
# T241    1290
# H094     928
# T227     828
# I707     805
# F176     765
# E651     728
# D112     726
# T251     722
# A109     712
# Name: nomartic, dtype: int64

# %%
bus='T222'
gasto_bus(df, bus)
# Out:
# Año con mayor gasto total,  2012 distribuido:
# nomfamia
# ELEMENTOS MOTOR              8214.44
# MANO DE OBRA                 7955.96
# VARIOS                       3877.86
# MATERIAL ELECTRICO           2910.78
# MATERIAL CAJAS CAMBIO        1005.48
# TORNILLERIA Y VARIOS          326.00
# AIRE ACOND. Y CALEFACCION     288.86
# BOMBAS AGUA Y VALVULAS        214.46
# RODAMIENTOS                   132.82
# MATERIAL MECANICOS            118.94
# CARROCERIA                     93.22
# CORREAS                        34.60
# Name: importe, dtype: float64
# Año con mayor gasto medio,  2010 distribuido:
# nomfamia
# LUNAS                        644.650000
# DIRECCIONES                  485.136667
# ELEMENTOS MOTOR              234.017500
# CARROCERIA                   222.222857
# MATERIAL ELECTRICO           145.390000
# VARIOS                       139.267143
# LATIGUILLO/MANGUITO/CABLE     54.000000
# CORREAS                       25.110000
# RODAMIENTOS                   15.290000
# TORNILLERIA Y VARIOS           8.760000
# MATERIAL CAJAS CAMBIO          6.020000
# MANO DE OBRA                   4.960000
# Name: importe, dtype: float64

# %%
df.columns
# Out:
# Index(['anyparte', 'numparte', 'numlinea', 'descrip', 'cantidad', 'precio',
#        'importe', 'prove mat', 'nomartic', 'fec_alta', 'preciouc', 'ctr_stock',
#        'nomalmac', 'prove art', 'nomfamia', 'nomunida', 'codigbus', 'fechaent',
#        'numkms', 'siniestro', 'descripcion', 'cliente', 'id_vehiculo',
#        'matricul', 'edad', 'numempre', 'nomempre', 'marca', 'modelo',
#        'carrocero', 'tipo', 'totkilom', 'dns_vehiculo', 'importe_teorico',
#        'descuento'],
#       dtype='object')

# %%
df.groupby('nomempre').nomartic.count()[df.groupby('nomempre').nomartic.count()>700].sort_values(ascending=False)
# Out:
# nomempre
# Transvia               14608
# Buñol                  11813
# Herca                  11359
# Fernanbus              10757
# Autos Diamond           6517
# Viajes Transvia         4968
# La Marina Gandiense     4667
# La Concepcion           4652
# Transvia Toledo         4559
# La Hispano Chelvana     3920
# HOSOJU                  3693
# Medtrast                3498
# La Serranica            2745
# Starbus                 2698
# Edetania                2239
# Travicoi                2068
# Urbanos de Torrent      1852
# Cave Talleres           1177
# Name: nomartic, dtype: int64

# %% [markdown]
# # Gasto por Empresa

# %%
def gasto_empresa(df, emp) :
    df_emp=df[df['nomempre']==emp]
    #df_emp.groupby('nomfamia').importe.mean().sort_values(ascending=False)
    #df_emp.groupby('nomfamia').importe.mean().sort_values(ascending=False)
    
    
    #Gasto total por familia
    x_emp=df_emp.groupby('nomfamia').importe.sum().sort_values(ascending=False)
    y_emp=df_emp.groupby('nomfamia').importe.sum().sort_values(ascending=False).index

    plt.figure(figsize=(15,15))
    sns.set(style='darkgrid')

    sns.barplot(x=x_emp, y=y_emp,data=df)
    plt.title('Empresa '+emp+' Gasto total por familia')
    plt.show()
    

    
    ##### Gasto total por año
    
    y_emp=df_emp.groupby('anyparte').importe.sum()
    x_emp=list(df_emp.groupby('anyparte').importe.sum().index)


    fig,axis = plt.subplots(1,1, figsize=(15,8))
    axis.plot(x_emp,y_emp,'go-',label='importe',linewidth=1,alpha=1) # creación del gráfico
    plt.xticks(x_emp)
    axis.legend(loc='best')
    plt.title('Empresa '+emp+' Gasto total por año')
    plt.grid()
    plt.show() 
    
   
    #####
    año_max = df_emp.groupby('anyparte').importe.sum().idxmax()
    print('\nAño con mayor gasto total', año_max ,'distribuido: \n')
    
    df_emp_año=df_emp[df_emp['anyparte']==año_max]
    gasto_año_max=df_emp_año.groupby('nomfamia').importe.sum().sort_values(ascending=False)
    display(gasto_año_max)
    
    #####
    
    print('\n')
    ### gasto medio
    x_emp=df_emp.groupby('nomfamia').importe.mean().sort_values(ascending=False)
    y_emp=df_emp.groupby('nomfamia').importe.mean().sort_values(ascending=False).index

    plt.figure(figsize=(15,15))
    sns.set(style='darkgrid')

    sns.barplot(x=x_emp, y=y_emp,data=df)
    plt.title('Empresa '+emp+' Gasto medio por familia')
    plt.show()
    #####
    
    ##### Gasto medio por año
    
    y_emp=df_emp.groupby('anyparte').importe.mean()
    x_emp=list(df_emp.groupby('anyparte').importe.mean().index)


    fig,axis = plt.subplots(1,1, figsize=(15,8))
    axis.plot(x_emp,y_emp,'go-',label='importe',linewidth=1,alpha=1) # creación del gráfico
    plt.xticks(x_emp)
    axis.legend(loc='best')
    plt.title('Autobus '+bus+' Gasto  medio por año')
    plt.grid()
    plt.show() 
    
    ##### detalles del gasto medio
    año_max = df_emp.groupby('anyparte').importe.mean().idxmax()
    print('\nAño con mayor gasto medio, ', año_max ,'distribuido: \n')
    
    df_emp_año=df_emp[df_emp['anyparte']==año_max]
    gasto_año_max=df_emp_año.groupby('nomfamia').importe.mean().sort_values(ascending=False)
    display(gasto_año_max)
    
    #display(df_bus.sample(5))

# %%
emp='Transvia' 
gasto_empresa(df, emp)
# Out:
# Año con mayor gasto total 2021 distribuido:
# nomfamia
# ELEMENTOS MOTOR              49797.33
# CUBIERTAS                    31935.51
# LUNAS                        27524.12
# MANO DE OBRA                 26714.16
# MATERIAL ELECTRICO           25430.31
# AIRE ACOND. Y CALEFACCION    13796.41
# CARROCERIA                   12194.12
# FRENOS                       10537.09
# FILTROS                      10501.41
# VARIOS                        8019.95
# EMBRAGUES                     7258.70
# SUSPENSION                    5742.59
# BOMBAS AGUA Y VALVULAS        4989.59
# MATERIAL CAJAS CAMBIO         3665.99
# MATERIAL PINTURA              3632.87
# IMAGEN Y SONIDO               2540.01
# TRANSMISION                   2131.52
# ACEITES Y LUBRICANTES         1968.05
# LATIGUILLO/MANGUITO/CABLE     1851.11
# DIRECCIONES                   1615.92
# RODAMIENTOS                   1414.61
# TORNILLERIA Y VARIOS          1131.91
# CORREAS                       1028.14
# PRODUCTOS QUIMICOS              51.15
# RESIDUOS                        40.76
# MATERIAL LIMPIEZA                8.94
# Name: importe, dtype: float64
# Año con mayor gasto medio,  2013 distribuido:
# nomfamia
# LUNAS                        852.006000
# DIRECCIONES                  533.580000
# AIRE ACOND. Y CALEFACCION    295.607500
# SUSPENSION                   286.471111
# EMBRAGUES                    264.336667
# CUBIERTAS                    240.215000
# FRENOS                       181.527222
# MANO DE OBRA                 175.063333
# MATERIAL ELECTRICO           174.776094
# BOMBAS AGUA Y VALVULAS       170.007222
# ACEITES Y LUBRICANTES        133.465000
# ELEMENTOS MOTOR              124.480833
# MATERIAL CAJAS CAMBIO        110.315385
# MATERIAL MECANICOS           100.190000
# CARROCERIA                    93.833913
# LATIGUILLO/MANGUITO/CABLE     88.622500
# MATERIAL PINTURA              67.412857
# VARIOS                        61.465938
# CORREAS                       33.670455
# FILTROS                       31.383243
# IMAGEN Y SONIDO               29.730000
# MATERIAL LIMPIEZA             26.900000
# TORNILLERIA Y VARIOS          13.510000
# ALMACEN COMPROMISOS            6.320000
# RODAMIENTOS                    4.980000
# Name: importe, dtype: float64

# %%
emp='Buñol' 
gasto_empresa(df, emp)
# Out:
# Año con mayor gasto total 2019 distribuido:
# nomfamia
# ELEMENTOS MOTOR              47342.95
# MANO DE OBRA                 27048.15
# MATERIAL ELECTRICO           21370.93
# LUNAS                        18969.00
# CUBIERTAS                    17720.21
# AIRE ACOND. Y CALEFACCION    14858.50
# CARROCERIA                   14072.09
# FRENOS                       11372.69
# BOMBAS AGUA Y VALVULAS        8630.58
# VARIOS                        8302.41
# MATERIAL CAJAS CAMBIO         6475.07
# EMBRAGUES                     4695.30
# FILTROS                       4351.98
# TRANSMISION                   2867.35
# RODAMIENTOS                   2831.26
# SUSPENSION                    2783.59
# LATIGUILLO/MANGUITO/CABLE     2711.03
# DIRECCIONES                   2413.76
# CORREAS                       1770.15
# MATERIAL PINTURA              1659.67
# IMAGEN Y SONIDO                992.77
# TORNILLERIA Y VARIOS           646.64
# ACEITES Y LUBRICANTES           91.70
# PRODUCTOS QUIMICOS              58.73
# MATERIAL LIMPIEZA               13.03
# ZF                              11.73
# RESIDUOS                         7.60
# Name: importe, dtype: float64
# Año con mayor gasto medio,  2017 distribuido:
# nomfamia
# LUNAS                        1642.018182
# EMBRAGUES                     457.610000
# BOMBAS AGUA Y VALVULAS        239.561750
# MATERIAL ELECTRICO            221.810870
# AIRE ACOND. Y CALEFACCION     212.224902
# TRANSMISION                   211.091935
# MANO DE OBRA                  201.153636
# DIRECCIONES                   189.970909
# MATERIAL CAJAS CAMBIO         149.410000
# CUBIERTAS                     124.803077
# IMAGEN Y SONIDO               124.221000
# SUSPENSION                    122.581724
# ELEMENTOS MOTOR               111.370208
# FRENOS                        101.193906
# MATERIAL PINTURA              101.137500
# RODAMIENTOS                    97.422273
# CARROCERIA                     71.157143
# LATIGUILLO/MANGUITO/CABLE      63.510000
# VARIOS                         63.224000
# ACEITES Y LUBRICANTES          36.403750
# CORREAS                        36.116667
# HERRAMIENTAS                   34.525000
# FILTROS                        32.398689
# PRODUCTOS QUIMICOS             18.500000
# TORNILLERIA Y VARIOS            9.451538
# Name: importe, dtype: float64

# %%
emp='Fernanbus' 
gasto_empresa(df, emp)
# Out:
# Año con mayor gasto total 2019 distribuido:
# nomfamia
# MANO DE OBRA                 61526.96
# ELEMENTOS MOTOR              43432.46
# LUNAS                        23686.40
# VARIOS                       15702.26
# FRENOS                       15155.58
# CUBIERTAS                    12693.60
# SUSPENSION                   11527.21
# BOMBAS AGUA Y VALVULAS       11479.79
# CARROCERIA                   11389.13
# MATERIAL ELECTRICO           10675.56
# FILTROS                       7947.75
# MATERIAL CAJAS CAMBIO         7499.73
# LATIGUILLO/MANGUITO/CABLE     6076.59
# MATERIAL PINTURA              4689.89
# AIRE ACOND. Y CALEFACCION     4142.17
# TRANSMISION                   1036.37
# CORREAS                       1016.71
# RODAMIENTOS                    775.54
# TORNILLERIA Y VARIOS           727.96
# EMBRAGUES                      703.86
# DIRECCIONES                    646.84
# HERRAMIENTAS                    61.97
# ACEITES Y LUBRICANTES           35.17
# PRODUCTOS QUIMICOS              11.40
# Name: importe, dtype: float64
# Año con mayor gasto medio,  2008 distribuido:
# nomfamia
# BOMBAS AGUA Y VALVULAS    395.000000
# LUNAS                     341.265000
# SUSPENSION                275.000000
# VARIOS                    242.879091
# FRENOS                    186.250000
# MANO DE OBRA              148.514000
# MATERIAL ELECTRICO        121.235882
# CORREAS                   113.441000
# SIN ASIGNAR               111.078333
# CARROCERIA                 89.193333
# FILTROS                    65.126667
# ELEMENTOS MOTOR            60.200000
# Name: importe, dtype: float64

# %% [markdown]
# # Gasto pòr edad

# %%
df.columns
# Out:
# Index(['anyparte', 'numparte', 'numlinea', 'descrip', 'cantidad', 'precio',
#        'importe', 'prove mat', 'nomartic', 'fec_alta', 'preciouc', 'ctr_stock',
#        'nomalmac', 'prove art', 'nomfamia', 'nomunida', 'codigbus', 'fechaent',
#        'numkms', 'siniestro', 'descripcion', 'cliente', 'id_vehiculo',
#        'matricul', 'edad', 'numempre', 'nomempre', 'marca', 'modelo',
#        'carrocero', 'tipo', 'totkilom', 'dns_vehiculo', 'importe_teorico',
#        'descuento'],
#       dtype='object')

# %%
df.groupby('edad').edad.count().sort_index(ascending=True)
# Out:
# edad
# -1.0      3892
#  0.0        16
#  1.0       108
#  2.0       496
#  3.0      1267
#  4.0      6001
#  5.0      7214
#  6.0      5269
#  7.0      2252
#  8.0      3730
#  9.0      2298
#  10.0      760
#  11.0     3080
#  12.0     4428
#  13.0     4201
#  14.0    10646
#  15.0    10493
#  16.0    10153
#  17.0     5611
#  18.0     4411
#  19.0     3583
#  20.0     2676
#  21.0     2158
#  22.0       96
#  23.0      136
#  24.0      225
#  25.0       76
#  26.0        2
#  27.0      195
#  29.0      134
#  30.0      440
#  31.0       11
#  32.0       22
#  34.0      166
#  37.0      363
#  38.0        2
#  39.0      841
#  40.0      294
#  42.0        1
#  43.0        6
#  44.0       10
#  63.0        2
#  64.0       18
#  73.0       64
# Name: edad, dtype: int64

# %%
  
df_edad=df.groupby('edad').edad.count().sort_index(ascending=True)

x = df_edad.index
y= df_edad


fig,axis = plt.subplots(1,1, figsize=(15,8))
axis.plot(x,y,'go-',label='precio',linewidth=1,alpha=1) # creación del gráfico


axis.legend(loc='best')
plt.grid()
plt.show()

# %%
df.groupby('edad').importe.mean().sort_index(ascending=True)
# Out:
# edad
# -1.0      95.506711
#  0.0     158.073750
#  1.0      96.637778
#  2.0     104.686290
#  3.0     105.261784
#  4.0      87.181546
#  5.0     110.159376
#  6.0     121.306117
#  7.0     127.968419
#  8.0     155.238413
#  9.0     131.592585
#  10.0    140.130329
#  11.0    132.065623
#  12.0    112.486868
#  13.0    143.618010
#  14.0    125.384501
#  15.0    132.479388
#  16.0    133.226740
#  17.0    127.351543
#  18.0    123.599433
#  19.0    120.676793
#  20.0    125.236536
#  21.0    125.164852
#  22.0     85.039062
#  23.0    228.246029
#  24.0    161.845733
#  25.0     56.928289
#  26.0     73.930000
#  27.0    109.247128
#  29.0     61.926716
#  30.0     73.041591
#  31.0     63.376364
#  32.0     35.652273
#  34.0     84.735602
#  37.0    116.755620
#  38.0     72.300000
#  39.0    114.057610
#  40.0    107.377993
#  42.0     86.190000
#  43.0     74.718333
#  44.0     86.662000
#  63.0     21.600000
#  64.0     63.072222
#  73.0     46.901250
# Name: importe, dtype: float64

# %%
df_edad=df.groupby('edad').importe.sum().sort_index(ascending=True)
df_edad_mean=df.groupby('edad').importe.mean().sort_index(ascending=True)
x = df_edad.index
y= df_edad
x_mean = df_edad_mean.index
y_mean= df_edad_mean

fig,axis = plt.subplots(2,1, figsize=(15,8))
axis[0].plot(x_mean,y_mean,'go-',label='precio_medio',linewidth=1,alpha=1) # creación del gráfico
axis[1].plot(x,y,'ro-',label='precio',linewidth=1,alpha=1) # creación del gráfico

axis[0].legend(loc='best')
axis[1].legend(loc='best')
plt.grid()
plt.show()
